# %% [markdown]
# <a href="https://colab.research.google.com/github/joaovitordeon/ENEM_2016_codenation/blob/master/best_codenation_ENEM_2016.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise exploratória

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! ls "/content/drive/My Drive/Colab Notebooks/codenation_ENEM"
# Out:
# best_codenation_ENEM_2016.ipynb  test.csv
# codenation_ENEM_2016.ipynb	 train.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv("/content/drive/My Drive/Colab Notebooks/codenation_ENEM/train.csv")

# %%
df_test = pd.read_csv("/content/drive/My Drive/Colab Notebooks/codenation_ENEM/test.csv")

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13730 entries, 0 to 13729
# Columns: 167 entries, Unnamed: 0 to Q050
# dtypes: float64(28), int64(79), object(60)
# memory usage: 17.5+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4576 entries, 0 to 4575
# Data columns (total 47 columns):
# NU_INSCRICAO              4576 non-null object
# CO_UF_RESIDENCIA          4576 non-null int64
# SG_UF_RESIDENCIA          4576 non-null object
# NU_IDADE                  4576 non-null int64
# TP_SEXO                   4576 non-null object
# TP_COR_RACA               4576 non-null int64
# TP_NACIONALIDADE          4576 non-null int64
# TP_ST_CONCLUSAO           4576 non-null int64
# TP_ANO_CONCLUIU           4576 non-null int64
# TP_ESCOLA                 4576 non-null int64
# TP_ENSINO                 1480 non-null float64
# IN_TREINEIRO              4576 non-null int64
# TP_DEPENDENCIA_ADM_ESC    1480 non-null float64
# IN_BAIXA_VISAO            4576 non-null int64
# IN_CEGUEIRA               4576 non-null int64
# IN_SURDEZ                 4576 non-null int64
# IN_DISLEXIA               4576 non-null int64
# IN_DISCALCULIA            4576 non-null int64
# IN_SABATISTA              4576 non-null int64
# IN_GESTANTE               4576 non-null int64
# IN_IDOSO                  4576 non-null int64
# TP_PRESENCA_CN            4576 non-null int64
# TP_PRESENCA_CH            4576 non-null int64
# TP_PRESENCA_LC            4576 non-null int64
# CO_PROVA_CN               4576 non-null object
# CO_PROVA_CH               4576 non-null object
# CO_PROVA_LC               4576 non-null object
# CO_PROVA_MT               4576 non-null object
# NU_NOTA_CN                3442 non-null float64
# NU_NOTA_CH                3442 non-null float64
# NU_NOTA_LC                3377 non-null float64
# TP_LINGUA                 4576 non-null int64
# TP_STATUS_REDACAO         3377 non-null float64
# NU_NOTA_COMP1             3377 non-null float64
# NU_NOTA_COMP2             3377 non-null float64
# NU_NOTA_COMP3             3377 non-null float64
# NU_NOTA_COMP4             3377 non-null float64
# NU_NOTA_COMP5             3377 non-null float64
# NU_NOTA_REDACAO           3377 non-null float64
# Q001                      4576 non-null object
# Q002                      4576 non-null object
# Q006                      4576 non-null object
# Q024                      4576 non-null object
# Q025                      4576 non-null object
# Q026                      4576 non-null object
# Q027                      2088 non-null object
# Q047                      4576 non-null object
# dtypes: float64(12), int64(20), object(15)
# memory usage: 1.6+ MB

# %% [markdown]
# **Transformar as colunas de treino iguais as de test. **

# %% [markdown]
# **Transformar colunas categoricas(dummies)**

# %% [markdown]
# **Verificar os as colunas com muitos dados faltantes**

# %%
colunas = list(df_test.columns)

# %%
colunas.append("NU_NOTA_MT")

# %%
df_train = df_train[colunas]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13730 entries, 0 to 13729
# Data columns (total 48 columns):
# NU_INSCRICAO              13730 non-null object
# CO_UF_RESIDENCIA          13730 non-null int64
# SG_UF_RESIDENCIA          13730 non-null object
# NU_IDADE                  13730 non-null int64
# TP_SEXO                   13730 non-null object
# TP_COR_RACA               13730 non-null int64
# TP_NACIONALIDADE          13730 non-null int64
# TP_ST_CONCLUSAO           13730 non-null int64
# TP_ANO_CONCLUIU           13730 non-null int64
# TP_ESCOLA                 13730 non-null int64
# TP_ENSINO                 4282 non-null float64
# IN_TREINEIRO              13730 non-null int64
# TP_DEPENDENCIA_ADM_ESC    4282 non-null float64
# IN_BAIXA_VISAO            13730 non-null int64
# IN_CEGUEIRA               13730 non-null int64
# IN_SURDEZ                 13730 non-null int64
# IN_DISLEXIA               13730 non-null int64
# IN_DISCALCULIA            13730 non-null int64
# IN_SABATISTA              13730 non-null int64
# IN_GESTANTE               13730 non-null int64
# IN_IDOSO                  13730 non-null int64
# TP_PRESENCA_CN            13730 non-null int64
# TP_PRESENCA_CH            13730 non-null int64
# TP_PRESENCA_LC            13730 non-null int64
# CO_PROVA_CN               13730 non-null object
# CO_PROVA_CH               13730 non-null object
# CO_PROVA_LC               13730 non-null object
# CO_PROVA_MT               13730 non-null object
# NU_NOTA_CN                10341 non-null float64
# NU_NOTA_CH                10341 non-null float64
# NU_NOTA_LC                10133 non-null float64
# TP_LINGUA                 13730 non-null int64
# TP_STATUS_REDACAO         10133 non-null float64
# NU_NOTA_COMP1             10133 non-null float64
# NU_NOTA_COMP2             10133 non-null float64
# NU_NOTA_COMP3             10133 non-null float64
# NU_NOTA_COMP4             10133 non-null float64
# NU_NOTA_COMP5             10133 non-null float64
# NU_NOTA_REDACAO           10133 non-null float64
# Q001                      13730 non-null object
# Q002                      13730 non-null object
# Q006                      13730 non-null object
# Q024                      13730 non-null object
# Q025                      13730 non-null object
# Q026                      13730 non-null object
# Q027                      6357 non-null object
# Q047                      13730 non-null object
# NU_NOTA_MT                10133 non-null float64
# dtypes: float64(13), int64(20), object(15)
# memory usage: 5.0+ MB

# %% [markdown]
# **SG_UF_RESIDENCIA inútil para o problema visto que ja temos o numero das unidades federativas**

# %% [markdown]
# **TP_ENSINO, TP_DEPENDENCIA_ADM_ESC, Q027  com muitos dados faltantes**

# %% [markdown]
# **Colunas CO_PROVA_... são das cores das provas, o que não agrega nada ao modelo**

# %% [markdown]
# **Transformar os dados categoricos(dummies)**

# %%
#criando copia dos df'sinfo()
train = df_train.copy()
test = df_test.copy()

# %%
sns.heatmap(train.corr())

# %% [markdown]
# **apagar as linhas que tem NU_NOTA_MT como NANs**

# %%
train = train[~np.isnan(train.NU_NOTA_MT)]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10133 entries, 0 to 13729
# Data columns (total 48 columns):
# NU_INSCRICAO              10133 non-null object
# CO_UF_RESIDENCIA          10133 non-null int64
# SG_UF_RESIDENCIA          10133 non-null object
# NU_IDADE                  10133 non-null int64
# TP_SEXO                   10133 non-null object
# TP_COR_RACA               10133 non-null int64
# TP_NACIONALIDADE          10133 non-null int64
# TP_ST_CONCLUSAO           10133 non-null int64
# TP_ANO_CONCLUIU           10133 non-null int64
# TP_ESCOLA                 10133 non-null int64
# TP_ENSINO                 3639 non-null float64
# IN_TREINEIRO              10133 non-null int64
# TP_DEPENDENCIA_ADM_ESC    3639 non-null float64
# IN_BAIXA_VISAO            10133 non-null int64
# IN_CEGUEIRA               10133 non-null int64
# IN_SURDEZ                 10133 non-null int64
# IN_DISLEXIA               10133 non-null int64
# IN_DISCALCULIA            10133 non-null int64
# IN_SABATISTA              10133 non-null int64
# IN_GESTANTE               10133 non-null int64
# IN_IDOSO                  10133 non-null int64
# TP_PRESENCA_CN            10133 non-null int64
# TP_PRESENCA_CH            10133 non-null int64
# TP_PRESENCA_LC            10133 non-null int64
# CO_PROVA_CN               10133 non-null object
# CO_PROVA_CH               10133 non-null object
# CO_PROVA_LC               10133 non-null object
# CO_PROVA_MT               10133 non-null object
# NU_NOTA_CN                10097 non-null float64
# NU_NOTA_CH                10097 non-null float64
# NU_NOTA_LC                10133 non-null float64
# TP_LINGUA                 10133 non-null int64
# TP_STATUS_REDACAO         10133 non-null float64
# NU_NOTA_COMP1             10133 non-null float64
# NU_NOTA_COMP2             10133 non-null float64
# NU_NOTA_COMP3             10133 non-null float64
# NU_NOTA_COMP4             10133 non-null float64
# NU_NOTA_COMP5             10133 non-null float64
# NU_NOTA_REDACAO           10133 non-null float64
# Q001                      10133 non-null object
# Q002                      10133 non-null object
# Q006                      10133 non-null object
# Q024                      10133 non-null object
# Q025                      10133 non-null object
# Q026                      10133 non-null object
# Q027                      4007 non-null object
# Q047                      10133 non-null object
# NU_NOTA_MT                10133 non-null float64
# dtypes: float64(13), int64(20), object(15)
# memory usage: 3.8+ MB

# %%
sns.boxplot(train.NU_NOTA_MT, color='m')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
train.drop(columns=['SG_UF_RESIDENCIA','TP_ENSINO', 'TP_DEPENDENCIA_ADM_ESC', 'Q027','CO_PROVA_CN','CO_PROVA_CH','CO_PROVA_LC','CO_PROVA_MT'], inplace=True)
test.drop(columns=['SG_UF_RESIDENCIA','TP_ENSINO', 'TP_DEPENDENCIA_ADM_ESC', 'Q027','CO_PROVA_CN','CO_PROVA_CH','CO_PROVA_LC','CO_PROVA_MT'], inplace=True)

# %%
#nao fazer dummie da coluna de inscrição nem das notas de mat
train = pd.get_dummies(train, columns=['TP_SEXO','Q001', 'Q002','Q006', 'Q024', 'Q025', 'Q026', 'Q047'])

test = pd.get_dummies(test, columns=['TP_SEXO','Q001', 'Q002','Q006', 'Q024', 'Q025', 'Q026', 'Q047'])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10133 entries, 0 to 13729
# Data columns (total 82 columns):
# NU_INSCRICAO         10133 non-null object
# CO_UF_RESIDENCIA     10133 non-null int64
# NU_IDADE             10133 non-null int64
# TP_COR_RACA          10133 non-null int64
# TP_NACIONALIDADE     10133 non-null int64
# TP_ST_CONCLUSAO      10133 non-null int64
# TP_ANO_CONCLUIU      10133 non-null int64
# TP_ESCOLA            10133 non-null int64
# IN_TREINEIRO         10133 non-null int64
# IN_BAIXA_VISAO       10133 non-null int64
# IN_CEGUEIRA          10133 non-null int64
# IN_SURDEZ            10133 non-null int64
# IN_DISLEXIA          10133 non-null int64
# IN_DISCALCULIA       10133 non-null int64
# IN_SABATISTA         10133 non-null int64
# IN_GESTANTE          10133 non-null int64
# IN_IDOSO             10133 non-null int64
# TP_PRESENCA_CN       10133 non-null int64
# TP_PRESENCA_CH       10133 non-null int64
# TP_PRESENCA_LC       10133 non-null int64
# NU_NOTA_CN           10097 non-null float64
# NU_NOTA_CH           10097 non-null float64
# NU_NOTA_LC           10133 non-null float64
# TP_LINGUA            10133 non-null int64
# TP_STATUS_REDACAO    10133 non-null float64
# NU_NOTA_COMP1        10133 non-null float64
# NU_NOTA_COMP2        10133 non-null float64
# NU_NOTA_COMP3        10133 non-null float64
# NU_NOTA_COMP4        10133 non-null float64
# NU_NOTA_COMP5        10133 non-null float64
# NU_NOTA_REDACAO      10133 non-null float64
# NU_NOTA_MT           10133 non-null float64
# TP_SEXO_F            10133 non-null uint8
# TP_SEXO_M            10133 non-null uint8
# Q001_A               10133 non-null uint8
# Q001_B               10133 non-null uint8
# Q001_C               10133 non-null uint8
# Q001_D               10133 non-null uint8
# Q001_E               10133 non-null uint8
# Q001_F               10133 non-null uint8
# Q001_G               10133 non-null uint8
# Q001_H               10133 non-null uint8
# Q002_A               10133 non-null uint8
# Q002_B               10133 non-null uint8
# Q002_C               10133 non-null uint8
# Q002_D               10133 non-null uint8
# Q002_E               10133 non-null uint8
# Q002_F               10133 non-null uint8
# Q002_G               10133 non-null uint8
# Q002_H               10133 non-null uint8
# Q006_A               10133 non-null uint8
# Q006_B               10133 non-null uint8
# Q006_C               10133 non-null uint8
# Q006_D               10133 non-null uint8
# Q006_E               10133 non-null uint8
# Q006_F               10133 non-null uint8
# Q006_G               10133 non-null uint8
# Q006_H               10133 non-null uint8
# Q006_I               10133 non-null uint8
# Q006_J               10133 non-null uint8
# Q006_K               10133 non-null uint8
# Q006_L               10133 non-null uint8
# Q006_M               10133 non-null uint8
# Q006_N               10133 non-null uint8
# Q006_O               10133 non-null uint8
# Q006_P               10133 non-null uint8
# Q006_Q               10133 non-null uint8
# Q024_A               10133 non-null uint8
# Q024_B               10133 non-null uint8
# Q024_C               10133 non-null uint8
# Q024_D               10133 non-null uint8
# Q024_E               10133 non-null uint8
# Q025_A               10133 non-null uint8
# Q025_B               10133 non-null uint8
# Q026_A               10133 non-null uint8
# Q026_B               10133 non-null uint8
# Q026_C               10133 non-null uint8
# Q047_A               10133 non-null uint8
# Q047_B               10133 non-null uint8
# Q047_C               10133 non-null uint8
# Q047_D               10133 non-null uint8
# Q047_E               10133 non-null uint8
# dtypes: float64(11), int64(20), object(1), uint8(50)
# memory usage: 3.0+ MB

# %%
train.dropna(axis='index', inplace=True)

# %%
sns.heatmap(train[train.columns[:-48]].corr())

# %% [markdown]
# **NU_NOTA_REDACAO com alta colinearidade , TP_SEXO também**

# %%
train.drop(columns=['NU_NOTA_REDACAO','TP_SEXO_F'], inplace=True)
test.drop(columns=['NU_NOTA_REDACAO','TP_SEXO_F'], inplace=True)

# %%
sns.heatmap(train[train.columns[:-48]].corr())

# %%
sns.heatmap(train[train.columns[42:]].corr())

# %% [markdown]
# **Q025, Q047_A, Q024_A com colinearidade**

# %%
train.drop(columns=['Q025_B','Q047_A','Q024_A'], inplace=True)
test.drop(columns=['Q025_B','Q047_A','Q024_A'], inplace=True)

# %%
sns.heatmap(train.corr())

# %%
#distribuição das notas nas 5 áreas
fig, ax = plt.subplots(1,4, figsize=(20,6))
d1 = sns.distplot(train['NU_NOTA_CN'], ax=ax[0], color='m')
d2 = sns.distplot(train['NU_NOTA_CH'], ax=ax[1], color='c')
d3 = sns.distplot(train['NU_NOTA_LC'], ax=ax[2], color='y')
d4 = sns.distplot(train['NU_NOTA_MT'], ax=ax[3], color='g')
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4576 entries, 0 to 4575
# Data columns (total 76 columns):
# NU_INSCRICAO         4576 non-null object
# CO_UF_RESIDENCIA     4576 non-null int64
# NU_IDADE             4576 non-null int64
# TP_COR_RACA          4576 non-null int64
# TP_NACIONALIDADE     4576 non-null int64
# TP_ST_CONCLUSAO      4576 non-null int64
# TP_ANO_CONCLUIU      4576 non-null int64
# TP_ESCOLA            4576 non-null int64
# IN_TREINEIRO         4576 non-null int64
# IN_BAIXA_VISAO       4576 non-null int64
# IN_CEGUEIRA          4576 non-null int64
# IN_SURDEZ            4576 non-null int64
# IN_DISLEXIA          4576 non-null int64
# IN_DISCALCULIA       4576 non-null int64
# IN_SABATISTA         4576 non-null int64
# IN_GESTANTE          4576 non-null int64
# IN_IDOSO             4576 non-null int64
# TP_PRESENCA_CN       4576 non-null int64
# TP_PRESENCA_CH       4576 non-null int64
# TP_PRESENCA_LC       4576 non-null int64
# NU_NOTA_CN           3442 non-null float64
# NU_NOTA_CH           3442 non-null float64
# NU_NOTA_LC           3377 non-null float64
# TP_LINGUA            4576 non-null int64
# TP_STATUS_REDACAO    3377 non-null float64
# NU_NOTA_COMP1        3377 non-null float64
# NU_NOTA_COMP2        3377 non-null float64
# NU_NOTA_COMP3        3377 non-null float64
# NU_NOTA_COMP4        3377 non-null float64
# NU_NOTA_COMP5        3377 non-null float64
# TP_SEXO_M            4576 non-null uint8
# Q001_A               4576 non-null uint8
# Q001_B               4576 non-null uint8
# Q001_C               4576 non-null uint8
# Q001_D               4576 non-null uint8
# Q001_E               4576 non-null uint8
# Q001_F               4576 non-null uint8
# Q001_G               4576 non-null uint8
# Q001_H               4576 non-null uint8
# Q002_A               4576 non-null uint8
# Q002_B               4576 non-null uint8
# Q002_C               4576 non-null uint8
# Q002_D               4576 non-null uint8
# Q002_E               4576 non-null uint8
# Q002_F               4576 non-null uint8
# Q002_G               4576 non-null uint8
# Q002_H               4576 non-null uint8
# Q006_A               4576 non-null uint8
# Q006_B               4576 non-null uint8
# Q006_C               4576 non-null uint8
# Q006_D               4576 non-null uint8
# Q006_E               4576 non-null uint8
# Q006_F               4576 non-null uint8
# Q006_G               4576 non-null uint8
# Q006_H               4576 non-null uint8
# Q006_I               4576 non-null uint8
# Q006_J               4576 non-null uint8
# Q006_K               4576 non-null uint8
# Q006_L               4576 non-null uint8
# Q006_M               4576 non-null uint8
# Q006_N               4576 non-null uint8
# Q006_O               4576 non-null uint8
# Q006_P               4576 non-null uint8
# Q006_Q               4576 non-null uint8
# Q024_B               4576 non-null uint8
# Q024_C               4576 non-null uint8
# Q024_D               4576 non-null uint8
# Q024_E               4576 non-null uint8
# Q025_A               4576 non-null uint8
# Q026_A               4576 non-null uint8
# Q026_B               4576 non-null uint8
# Q026_C               4576 non-null uint8
# Q047_B               4576 non-null uint8
# Q047_C               4576 non-null uint8
# Q047_D               4576 non-null uint8
# Q047_E               4576 non-null uint8
# dtypes: float64(9), int64(20), object(1), uint8(46)
# memory usage: 1.2+ MB

# %%
test.dropna(axis='index', inplace=True)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor

# %%
X = train.drop(columns=['NU_INSCRICAO','NU_NOTA_MT'])
y = train.NU_NOTA_MT

# %%
parameters = {#'nthread':4, #when use hyperthread, xgboost may become slower
              'objective':'reg:linear',
              'learning_rate': .03, #so called `eta` value
              'max_depth': 5,
              'min_child_weight': 4,
              'silent': 1,
              'subsample': 0.7,
              'colsample_bytree': 0.5,
              'n_estimators': 250}

# %%
clf = XGBRegressor(**parameters) # 60, 4
clf.fit( X, y, verbose=False)
pred = clf.predict(test.drop(columns=['NU_INSCRICAO']))

# %%
answer = pd.DataFrame()
answer['NU_INSCRICAO'] = test.NU_INSCRICAO
answer['NU_NOTA_MT'] = pred

# %%
answer.head()
# Out:
#                                NU_INSCRICAO  NU_NOTA_MT
# 0  73ff9fcc02f0a99919906c942c2e1a1042cdcf98  432.549835
# 1  71a95f9f1b91a82c65ad94abbdf9f54e6066f968  448.448914
# 2  b38a03232f43b11c9d0788abaf060f7366053b6d  597.027527
# 4  715494628a50142ce8cb17191cfe6d0f3cae0934  551.735962
# 5  e656d6bad65c93fb2880f1eba5037008c8e75774  491.180389

# %%
answer.to_csv('answer.csv', index=False)

# %%
from google.colab import files
files.download('answer.csv')
